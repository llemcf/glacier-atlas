# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
from datetime import datetime
annee_float = int(datetime.now().year)
print(annee_float)  # Résultat : 2026.0
# Out:
# 2026

# %%
import geopandas as gpd
df = gpd.read_file('/Users/guillem.carcanade/Documents/guillem/glacier_atlas/data/randolph_glacier_inventory_7/rgi2000_v70_vector.shp')

# %%
df['glac_name'].unique()
# Out:
# array(['FR4N01166I01 de la Muzelle',
#        'FR4N01166H08-10 de la Grande Montagne',
#        'FR4N01166H06 du Vallon de Lanchatra', ...,
#        'Schladminger Gletscher,', 'Hoellentalferner',
#        'Nordlicher Schneeferner'], dtype=object)
