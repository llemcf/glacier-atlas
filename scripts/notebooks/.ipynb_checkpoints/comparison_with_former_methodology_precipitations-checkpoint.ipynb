# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import folium
from deepki.http.api_utils import make_heatwaves, make_precipitations
from deepki.ddk.query import Query
import matplotlib.pyplot as plt
from tqdm import tqdm

colors = ["#007500", "#00D100", "#8AFF8A", "#FFFF00", "#FFA500", "#FF0000"]
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Fetching data

# %%
project = "primonial"

# %%
buildings_df = Query(
    "prod",
    fields=[
        "*",
    ],
    collection="buildings",
    filters={"project_id": [project]},
    exclude={},
).compute()

buildings_df = buildings_df[buildings_df["current_perimeter"]]
buildings_df = buildings_df.reset_index(drop = True)
# Out:
# INFO:deepki.ddk.query:Loading data for projects in platform https://deepki-ready.deepki.com
#   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:deepki.ddk.query:Loading data for projects in platform https://esg.realassets.axa-im.com
# 0it [00:00, ?it/s]
# INFO:deepki.ddk.query:Loading data for projects in platform https://osfi.deepki.com
# 0it [00:00, ?it/s]
# INFO:deepki.ddk.query:Loading data for projects in platform https://ccs.deepki.com
# 0it [00:00, ?it/s]

# %%
buildings_df.to_csv("primonial_0910.csv", sep=";")

# %%
buildings_df.shape
# Out:
# (1021, 226)

# %% [markdown]
# # Heatwaves

# %%
list_results_rcp45 = []
list_results_rcp85 = []
list_results_ssp245 = []
list_results_ssp585 = []

for lat_val, lon_val in tqdm(zip(buildings_df.lat.values, buildings_df.lon.values)):
        
    dic_results_rcp45 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"heatwaves_rcp45"}
    list_results_rcp45.append(dic_results_rcp45)
    dic_results_rcp85 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"heatwaves_rcp85"}
    list_results_rcp85.append(dic_results_rcp85)
    dic_results_ssp245 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"heatwaves_ssp245"}
    list_results_ssp245.append(dic_results_ssp245)
    dic_results_ssp585 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"heatwaves_ssp585"}
    list_results_ssp585.append(dic_results_ssp585)

results_rcp45 = pd.DataFrame(make_heatwaves(inputs=list_results_rcp45))
results_rcp85 = pd.DataFrame(make_heatwaves(inputs=list_results_rcp85))
results_ssp245 = pd.DataFrame(make_heatwaves(inputs=list_results_ssp245))
results_ssp585 = pd.DataFrame(make_heatwaves(inputs=list_results_ssp585))
# Out:
# 1021it [00:00, 698366.66it/s]

# %% [markdown]
# # Merging and processing data

# %%
summary_df = pd.merge(buildings_df[["building_id", "building_name", "lat", "lon", "city", "country", "address"]],
                      results_rcp45[["continuous_score_heatwaves", "discrete_score_heatwaves", "lat_building", "lon_building"]],
                      how = "left",
                      left_on = ["lat", "lon"],
                      right_on = ["lat_building", "lon_building"])

summary_df = summary_df.drop_duplicates()

summary_df["rank_rcp45"] = summary_df['continuous_score_heatwaves'].rank(method='min')

# %%
summary_df = pd.merge(summary_df,
                      results_rcp85[["continuous_score_heatwaves", "discrete_score_heatwaves", "lat_building", "lon_building"]],
                      how = "left",
                      on = ["lat_building", "lon_building"],
                      suffixes = ("_rcp45", "_rcp85")
                     )

summary_df = summary_df.drop_duplicates()

summary_df["rank_rcp85"] = summary_df['continuous_score_heatwaves_rcp85'].rank(method='min')

# %%
summary_df = pd.merge(summary_df,
                      results_ssp245[['continuous_score_heatwaves', 'discrete_score_heatwaves', 'average_heatwaves_day_temperature_2045_2055', 'yearly_number_heatwaves_days_2045_2055', 'heatwaves_beginning_threshold', 'heatwaves_detection_threshold', 'heatwaves_interruption_threshold', "lat_building", "lon_building"]],
                      how = "left",
                      on = ["lat_building", "lon_building"],
                     )

summary_df = summary_df.drop_duplicates()

summary_df["rank_ssp245"] = summary_df['continuous_score_heatwaves'].rank(method='min')

# %%
summary_df = pd.merge(summary_df,
                      results_ssp585[['continuous_score_heatwaves', 'discrete_score_heatwaves', 'average_heatwaves_day_temperature_2045_2055', 'yearly_number_heatwaves_days_2045_2055', "lat_building", "lon_building"]],
                      how = "left",
                      on = ["lat_building", "lon_building"],
                      suffixes = ("_ssp245", "_ssp585")
                     )

summary_df = summary_df.drop_duplicates().drop(columns = ["lat_building", "lon_building"])

summary_df["rank_ssp585"] = summary_df['continuous_score_heatwaves_ssp585'].rank(method='min')

# %%
summary_df["diff_rank_ssp245_rcp45"] = summary_df["rank_ssp245"] - summary_df["rank_rcp45"]
summary_df["diff_rank_ssp585_rcp85"] = summary_df["rank_ssp585"] - summary_df["rank_rcp85"]

summary_df["diff_discrete_score_ssp245_rcp45"] = summary_df["discrete_score_heatwaves_ssp245"] - summary_df["discrete_score_heatwaves_rcp45"]
summary_df["diff_discrete_score_ssp585_rcp85"] = summary_df["discrete_score_heatwaves_ssp585"] - summary_df["discrete_score_heatwaves_rcp85"]

# %% [markdown]
# # Results

# %% [markdown]
# ## Change in raking among project's assets

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 4), sharex = True, sharey = True)

ax1.hist(summary_df["diff_rank_ssp245_rcp45"])
ax1.set_title(f"Change in ranking of {project} assets in RCP/SSP2-4.5")
ax2.hist(summary_df["diff_rank_ssp585_rcp85"])
ax2.set_title(f"Change in ranking of {project} assets in RCP/SSP5-8.5");

# %%
nb_bdgs = len(summary_df)
print(f"Split of change in ranking for {project} assets in RCP/SSP2-4.5 scenario")
summary_df['magnitude_of_ranking_chg_ssp245_rcp45'] = pd.cut(summary_df['diff_rank_ssp245_rcp45'], bins=[-nb_bdgs, -nb_bdgs/2, -nb_bdgs/10, nb_bdgs/10, nb_bdgs/2, nb_bdgs], labels = ["High decrease in raking", "Moderate decrease in raking", "Stable ranking", "Moderate increase in raking", "High increase in raking"], right=True)
summary_df['magnitude_of_ranking_chg_ssp245_rcp45'].value_counts()
# Out:
# Split of change in ranking for primonial assets in RCP/SSP2-4.5 scenario
# Stable ranking                 735
# Moderate decrease in raking    173
# Moderate increase in raking     98
# High decrease in raking         11
# High increase in raking          4
# Name: magnitude_of_ranking_chg_ssp245_rcp45, dtype: int64

# %%
print(f"Split of change in ranking for {project} assets in RCP/SSP5-8.5 scenario")
summary_df['magnitude_of_ranking_chg_ssp585_rcp85'] = pd.cut(summary_df['diff_rank_ssp585_rcp85'], bins=[-nb_bdgs, -nb_bdgs/2, -nb_bdgs/10, nb_bdgs/10, nb_bdgs/2, nb_bdgs], labels = ["High decrease in raking", "Moderate decrease in raking", "Stable ranking", "Moderate increase in raking", "High increase in raking"], right=True)
summary_df['magnitude_of_ranking_chg_ssp585_rcp85'].value_counts()
# Out:
# Split of change in ranking for primonial assets in RCP/SSP5-8.5 scenario
# Stable ranking                 641
# Moderate decrease in raking    210
# Moderate increase in raking    156
# High decrease in raking         14
# High increase in raking          0
# Name: magnitude_of_ranking_chg_ssp585_rcp85, dtype: int64

# %%
m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 4)

for i, row in summary_df[summary_df['magnitude_of_ranking_chg_ssp245_rcp45'] != 'Stable raking'].iterrows():
    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'High decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#007500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'Moderate decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#00D100",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'Moderate increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FFA500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)
    
    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'High increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FF0000",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)
        
m.save(f"projects_comparison/{project}_greatest_change_in_ranking_ssp245_rcp45.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5009c12a6cf9e6646883114d946e8fe5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5009c12a6cf9e6646883114d946e8fe5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5009c12a6cf9e6646883114d946e8fe5 = L.map(
#                 &quot;map_5009c12a6cf9e6646883114d946e8fe5&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ee5edab004f621bb1f98337650ffac4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5009c12a6cf9e6646883114d946e8fe5);
#
#
#             var circle_ccc9327d73b0bd06d5c59f0736b4f2c6 = L.circle(
#                 [48.0140995, -4.0815765],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5009c12a6cf9e6646883114d946e8fe5);
#
#
#         var popup_f8ec37e4fc63c54280b8c399b94063f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78492f1faac067bcb70d88079a1da752 = $(`&lt;div id=&quot;html_78492f1faac067bcb70d88079a1da752&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0111&lt;br&gt; New ranking: 1&lt;br&gt; Old ranking: 125&lt;/div&gt;`)[0];
#                 popup_f8ec37e4fc63c54280b8c399b94063f2.setContent(html_78492f1faac067bcb70d88079a1da752);
#
#
#
#         circle_ccc9327d73b0bd06d5c59f0736b4f2c6.bindPopup(popup_f8ec37e4fc63c54280b8c399b94063f2)
#         ;
#
#
#
#
#             var circle_5705e0ae94d21d48f749c5347a4a4f1e = L.circle(
#                 [48.9276597, 1.986697],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFA500&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFA500&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5009c12a6cf9e6646883114d946e8fe5);
#
#
#         var popup_d8e93090f3ee42899b6fc64ae34f45fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed902f484694c7c8b3beaf3ed2631428 = $(`&lt;div id=&quot;html_ed902f484694c7c8b3beaf3ed2631428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0115&lt;br&gt; New ranking: 436&lt;br&gt; Old ranking: 265&lt;/div&gt;`)[0];
#                 popup_d8e93090f3ee42899b6fc64ae34f45fb.setContent(html_ed902f484694c7c8b3beaf3ed2631428);
#
#
#
#         circle_5705e0ae94d21d48f749c5347a4a4f1e.bindPopup(popup_d8e93090f3ee42899b6fc64ae34f45fb)
#         ;
#
#
#
#
#             var circle_1a9b4a3c706e177a2c775a2a97f08a74 = L.circle(
#                 [48.03651199999999, 0.1733074],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5009c12a6cf9e6646883114d946e8fe5);
#
#
#         var popup_35d826aecc8bb55ccd22aef3599703d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4618b7152fe6fabfbad449d4c712edc = $(`&lt;div id=&quot;html_e4618b7152fe6fabfbad449d4c712edc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0124&lt;br&gt; New ranking: 311&lt;br&gt; Old ranking: 582&lt;/div&gt;`)[0];
#                 popup_35d826aecc8bb55ccd22aef3599703d6.setContent(html_e4618b7152fe6fabfbad449d4c712edc);
#
#
#
#         circle_1a9b4a3c706e177a2c775a2a97f08a74.bindPopup(popup_35d826aecc8bb55ccd22aef3599703d6)
#         ;
#
#
#
#
#             var circle_23dc2ebb14414fccb4bdf8005632b559 = L.circle(
#                 [43.5603829, 6.0115625],
#                 {&quot;b

# %%
m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 4)

for i, row in summary_df[summary_df['magnitude_of_ranking_chg_ssp585_rcp85'] != 'Stable raking'].iterrows():
    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'High decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#007500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'Moderate decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#00D100",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'Moderate increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FFA500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)
    
    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'High increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FF0000",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)
        
m.save(f"projects_comparison/{project}_greatest_change_in_ranking_ssp585_rcp85.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44c3e0c863ca11ed99bead8e4721beb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44c3e0c863ca11ed99bead8e4721beb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44c3e0c863ca11ed99bead8e4721beb0 = L.map(
#                 &quot;map_44c3e0c863ca11ed99bead8e4721beb0&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fb86acbbae9a60fb78323c5be4d50a8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44c3e0c863ca11ed99bead8e4721beb0);
#
#
#             var circle_4cac402819007dd5ea1eb153f7ee9c9d = L.circle(
#                 [48.8838446, 2.2622742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44c3e0c863ca11ed99bead8e4721beb0);
#
#
#         var popup_64bcffe3447a198a5083aef564cd120f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e6cb2a1ed440628461ec9ac327dedfc = $(`&lt;div id=&quot;html_9e6cb2a1ed440628461ec9ac327dedfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0014&lt;br&gt; New ranking: 363&lt;br&gt; Old ranking: 467&lt;/div&gt;`)[0];
#                 popup_64bcffe3447a198a5083aef564cd120f.setContent(html_9e6cb2a1ed440628461ec9ac327dedfc);
#
#
#
#         circle_4cac402819007dd5ea1eb153f7ee9c9d.bindPopup(popup_64bcffe3447a198a5083aef564cd120f)
#         ;
#
#
#
#
#             var circle_00c6078fd1d816a725e5420a605b1bfd = L.circle(
#                 [50.6910987, 3.1801869],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44c3e0c863ca11ed99bead8e4721beb0);
#
#
#         var popup_84aa1c5faba551b2ffd038d428d59a86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a9cfc087db5b60a173afcead3b80d71 = $(`&lt;div id=&quot;html_6a9cfc087db5b60a173afcead3b80d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0103&lt;br&gt; New ranking: 75&lt;br&gt; Old ranking: 189&lt;/div&gt;`)[0];
#                 popup_84aa1c5faba551b2ffd038d428d59a86.setContent(html_6a9cfc087db5b60a173afcead3b80d71);
#
#
#
#         circle_00c6078fd1d816a725e5420a605b1bfd.bindPopup(popup_84aa1c5faba551b2ffd038d428d59a86)
#         ;
#
#
#
#
#             var circle_b6221d41dd5e9be9f5b78fefbbbc4970 = L.circle(
#                 [48.8699468, 2.3248903],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44c3e0c863ca11ed99bead8e4721beb0);
#
#
#         var popup_f57834a837c2e2299aae7ae2f5f12f98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_198772395959d5638582617ecc5e94e6 = $(`&lt;div id=&quot;html_198772395959d5638582617ecc5e94e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0002&lt;br&gt; New ranking: 363&lt;br&gt; Old ranking: 467&lt;/div&gt;`)[0];
#                 popup_f57834a837c2e2299aae7ae2f5f12f98.setContent(html_198772395959d5638582617ecc5e94e6);
#
#
#
#         circle_b6221d41dd5e9be9f5b78fefbbbc4970.bindPopup(popup_f57834a837c2e2299aae7ae2f5f12f98)
#         ;
#
#
#
#
#             var circle_8d6d6058f1b5e7955b3a49b517396be4 = L.circle(
#                 [48.0140995, -4.0815765],
#                 {&quot;bubbli

# %% [markdown]
# ## Change in discrete scores

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 4), sharex = True, sharey = True)

ax1.hist(summary_df["diff_discrete_score_ssp245_rcp45"], bins = np.linspace(-5.5, 5.5, 12), rwidth = 0.5)
ax1.set_title(f"Change in discrete score of {project} assets in RCP/SSP2-4.5")
ax1.set_xticks(np.linspace(-5, 5, 11))

ax2.hist(summary_df["diff_discrete_score_ssp585_rcp85"], bins = np.linspace(-5.5, 5.5, 12), rwidth = 0.5)
ax2.set_title(f"Change in discrete score of {project} assets in RCP/SSP5-8.5")
ax2.set_xticks(np.linspace(-5, 5, 11));

# %%
print(f"Split of change in discrete score for {project} assets in RCP/SSP2-4.5 scenario")
summary_df['magnitude_of_discrete_score_chg_ssp245_rcp45'] = pd.cut(summary_df['diff_discrete_score_ssp245_rcp45'], bins=[-5.5, -3.5, -1.5, 1.5, 3.5, 5.5], labels = ["High decrease in discrete score (-4 or -5 pts)", "Moderate decrease in discrete score (-2 or -3 pts)", "Stable discrete score (-1, +1 pt or no change)", "Moderate increase in discrete score (+2 or +3 pts)", "High increase in discrete score (+4 or +5 pts)"], right=True)
summary_df['magnitude_of_discrete_score_chg_ssp245_rcp45'].value_counts()
# Out:
# Split of change in discrete score for primonial assets in RCP/SSP2-4.5 scenario
# Stable discrete score (-1, +1 pt or no change)        836
# Moderate decrease in discrete score (-2 or -3 pts)    178
# High decrease in discrete score (-4 or -5 pts)          6
# Moderate increase in discrete score (+2 or +3 pts)      1
# High increase in discrete score (+4 or +5 pts)          0
# Name: magnitude_of_discrete_score_chg_ssp245_rcp45, dtype: int64

# %%
print(f"Percentage of assets whose discrete score remains stable for {project} in SSP2-4.5 scenario: {round(len(summary_df[summary_df['magnitude_of_discrete_score_chg_ssp245_rcp45'] == 'Stable discrete score (-1, +1 pt or no change)'])/len(summary_df)*100,1)}%")
# Out:
# Percentage of assets whose discrete score remains stable for primonial in SSP2-4.5 scenario: 81.9%

# %%
summary_df['diff_discrete_score_ssp245_rcp45'].value_counts()
# Out:
# -1.0    508
#  0.0    325
# -2.0    160
# -3.0     18
# -4.0      4
#  1.0      3
# -5.0      2
#  2.0      1
# Name: diff_discrete_score_ssp245_rcp45, dtype: int64

# %%
print(f"Split of change in discrete score for {project} assets in RCP/SSP5-8.5 scenario")
summary_df['magnitude_of_discrete_score_chg_ssp585_rcp85'] = pd.cut(summary_df['diff_discrete_score_ssp585_rcp85'], bins=[-5.5, -3.5, -1.5, 1.5, 3.5, 5.5], labels = ["High decrease in discrete score (-4 or -5 pts)", "Moderate decrease in discrete score (-2 or -3 pts)", "Stable discrete score (-1, +1 pt or no change)", "Moderate increase in discrete score (+2 or +3 pts)", "High increase in discrete score (+4 or +5 pts)"], right=True)
summary_df['magnitude_of_discrete_score_chg_ssp585_rcp85'].value_counts()
# Out:
# Split of change in discrete score for primonial assets in RCP/SSP5-8.5 scenario
# Stable discrete score (-1, +1 pt or no change)        852
# Moderate decrease in discrete score (-2 or -3 pts)    154
# High decrease in discrete score (-4 or -5 pts)         15
# Moderate increase in discrete score (+2 or +3 pts)      0
# High increase in discrete score (+4 or +5 pts)          0
# Name: magnitude_of_discrete_score_chg_ssp585_rcp85, dtype: int64

# %%
print(f"Percentage of assets whose discrete score remains stable for {project} in SSP5-8.5 scenario: {round(len(summary_df[summary_df['magnitude_of_discrete_score_chg_ssp585_rcp85'] == 'Stable discrete score (-1, +1 pt or no change)'])/len(summary_df)*100,1)}%")
# Out:
# Percentage of assets whose discrete score remains stable for primonial in SSP5-8.5 scenario: 83.4%

# %%
loc = 'Magnitude of changes in heatwaves discrete scores for Primonial assets in SSP2-4.5 scenario'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   


m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 5)

#Defining groups:
stable = folium.FeatureGroup(name="Stable discrete score (0 or +/-1 pt)").add_to(m)
moderate_change = folium.FeatureGroup(name="Moderate change in discrete score (+/-2 or 3 pts)").add_to(m)
high_change = folium.FeatureGroup(name="High change in discrete score (+/-4 or 5 pts)").add_to(m)

for i, row in summary_df.iterrows():
    
    if row.magnitude_of_discrete_score_chg_ssp245_rcp45 in ['Stable discrete score (-1, +1 pt or no change)']:        
        stable.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "darkgreen",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_heatwaves_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_heatwaves_rcp45))))

    elif row.magnitude_of_discrete_score_chg_ssp245_rcp45 in ['Moderate decrease in discrete score (-2 or -3 pts)', 'Moderate increase in discrete score (+2 or +3 pts)']:        
        moderate_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "blue",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_heatwaves_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_heatwaves_rcp45))))
        
    elif row.magnitude_of_discrete_score_chg_ssp245_rcp45 in ['High decrease in discrete score (-4 or -5 pts)', 'High increase in discrete score (+4 or +5 pts)']:
        high_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "fuchsia",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_heatwaves_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_heatwaves_rcp45))))        

folium.LayerControl().add_to(m)
m.get_root().html.add_child(folium.Element(title_html))

m.save(f"projects_comparison/{project}_greatest_change_in_discrete_score_ssp245_rcp45.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a09e75aec5ffd4b9c308fd859198299 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Magnitude of changes in heatwaves discrete scores for Primonial assets in SSP2-4.5 scenario&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a09e75aec5ffd4b9c308fd859198299&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a09e75aec5ffd4b9c308fd859198299 = L.map(
#                 &quot;map_8a09e75aec5ffd4b9c308fd859198299&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0d3833015b2e868456529cf59d35e88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a09e75aec5ffd4b9c308fd859198299);
#
#
#             var feature_group_250e93faf178a6835ccad80cdf1b8923 = L.featureGroup(
#                 {}
#             ).addTo(map_8a09e75aec5ffd4b9c308fd859198299);
#
#
#             var circle_54e18f2f8ebf267744565bc1c054654f = L.circle(
#                 [48.8838446, 2.2622742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_250e93faf178a6835ccad80cdf1b8923);
#
#
#         var popup_b114fc08fa511a2adc8cba50972350d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae1f3f7d486dc7d0a0b7565c56422011 = $(`&lt;div id=&quot;html_ae1f3f7d486dc7d0a0b7565c56422011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0014&lt;br&gt; New disc. score: 3&lt;br&gt; Old disc. score: 4&lt;/div&gt;`)[0];
#                 popup_b114fc08fa511a2adc8cba50972350d2.setContent(html_ae1f3f7d486dc7d0a0b7565c56422011);
#
#
#
#         circle_54e18f2f8ebf267744565bc1c054654f.bindPopup(popup_b114fc08fa511a2adc8cba50972350d2)
#         ;
#
#
#
#
#             var circle_d5380a86fc0e06b8ca2463dcd43ba489 = L.circle(
#                 [48.8494766, 2.4192098],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_250e93faf178a6835ccad80cdf1b8923);
#
#
#         var popup_603ec8c47478728853b0dcc46fc0dbbc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9253ac10f21e1ddb23807b740f1360b8 = $(`&lt;div id=&quot;html_9253ac10f21e1ddb23807b740f1360b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0181&lt;br&gt; New disc. score: 3&lt;br&gt; Old disc. score: 4&lt;/div&gt;`)[0];
#                 popup_603ec8c47478728853b0dcc46fc0dbbc.setContent(html_9253ac10f21e1ddb23807b740f1360b8);
#
#
#
#         circle_d5380a86fc0e06b8ca2463dcd43ba489.bindPopup(popup_603ec8c47478728853b0dcc46fc0dbbc)
#         ;
#
#
#
#
#             var circle_d6543b0cfd56a005f9af7590554c8e69 = L.circle(
#                 [48.796792, 2.3218177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_250e93faf178a6835ccad80cdf1b8923);
#
#
#         var popup_7bf9e79bd37ff44bbb75715b8343a179 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5da7e82863b4e5629807ab6d285c8f71 = $(`&lt;div id=&quot;html_5da7e82863b4e5629807ab6d285c8f71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0008&lt;br&gt; New disc. sco

# %%
loc = 'Magnitude of changes in heatwaves discrete scores for Primonial assets in SSP5-8.5 scenario'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   


m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 5)

#Defining groups:
stable = folium.FeatureGroup(name="Stable discrete score (0 or +/-1 pt)").add_to(m)
moderate_change = folium.FeatureGroup(name="Moderate change in discrete score (+/-2 or 3 pts)").add_to(m)
high_change = folium.FeatureGroup(name="High change in discrete score (+/-4 or 5 pts)").add_to(m)

for i, row in summary_df.iterrows():
    
    if row.magnitude_of_discrete_score_chg_ssp585_rcp85 in ['Stable discrete score (-1, +1 pt or no change)']:        
        stable.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "darkgreen",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_heatwaves_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_heatwaves_rcp45))))

    elif row.magnitude_of_discrete_score_chg_ssp585_rcp85 in ['Moderate decrease in discrete score (-2 or -3 pts)', 'Moderate increase in discrete score (+2 or +3 pts)']:        
        moderate_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "blue",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_heatwaves_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_heatwaves_rcp45))))
        
    elif row.magnitude_of_discrete_score_chg_ssp585_rcp85 in ['High decrease in discrete score (-4 or -5 pts)', 'High increase in discrete score (+4 or +5 pts)']:
        high_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "fuchsia",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_heatwaves_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_heatwaves_rcp45))))        

folium.LayerControl().add_to(m)
m.get_root().html.add_child(folium.Element(title_html))

m.save(f"projects_comparison/{project}_greatest_change_in_discrete_score_ssp585_rcp85.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79d26aebaa743300f100cf6c4799334d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Magnitude of changes in heatwaves discrete scores for Primonial assets in SSP5-8.5 scenario&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79d26aebaa743300f100cf6c4799334d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79d26aebaa743300f100cf6c4799334d = L.map(
#                 &quot;map_79d26aebaa743300f100cf6c4799334d&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2655ed6e864ccde7639eb4a980d6408 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_79d26aebaa743300f100cf6c4799334d);
#
#
#             var feature_group_44c2ae560f58f372b5894f2287703161 = L.featureGroup(
#                 {}
#             ).addTo(map_79d26aebaa743300f100cf6c4799334d);
#
#
#             var circle_3ba5591710d06e4e0455eec10ba8d957 = L.circle(
#                 [48.8838446, 2.2622742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_44c2ae560f58f372b5894f2287703161);
#
#
#         var popup_24a4f6882006abddba63230a19a6d12e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1fe7dbb353ade28842d3c47cd2f204fe = $(`&lt;div id=&quot;html_1fe7dbb353ade28842d3c47cd2f204fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0014&lt;br&gt; New disc. score: 3&lt;br&gt; Old disc. score: 4&lt;/div&gt;`)[0];
#                 popup_24a4f6882006abddba63230a19a6d12e.setContent(html_1fe7dbb353ade28842d3c47cd2f204fe);
#
#
#
#         circle_3ba5591710d06e4e0455eec10ba8d957.bindPopup(popup_24a4f6882006abddba63230a19a6d12e)
#         ;
#
#
#
#
#             var circle_84611e7de0a25bfa446c2de7709320da = L.circle(
#                 [48.8494766, 2.4192098],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_44c2ae560f58f372b5894f2287703161);
#
#
#         var popup_07923a310f6ee5d87558209e2a2dbf5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01770d33eba1623bfc0f0f7fb776cd67 = $(`&lt;div id=&quot;html_01770d33eba1623bfc0f0f7fb776cd67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0181&lt;br&gt; New disc. score: 3&lt;br&gt; Old disc. score: 4&lt;/div&gt;`)[0];
#                 popup_07923a310f6ee5d87558209e2a2dbf5b.setContent(html_01770d33eba1623bfc0f0f7fb776cd67);
#
#
#
#         circle_84611e7de0a25bfa446c2de7709320da.bindPopup(popup_07923a310f6ee5d87558209e2a2dbf5b)
#         ;
#
#
#
#
#             var circle_29c3ff2833d4875dd5dc7d98f26dade8 = L.circle(
#                 [45.8024492, 4.7837361],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_44c2ae560f58f372b5894f2287703161);
#
#
#         var popup_a5240f1e3b1d48006b4c4fa39d7905d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc6dca2254d44c5a70f44ecb6808c090 = $(`&lt;div id=&quot;html_fc6dca2254d44c5a70f44ecb6808c090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0070&lt;br&gt; New disc. sc

# %% [markdown]
# # Saving summary excel

# %%
summary_df.to_excel(f"projects_comparison/{project}_summary_heatwaves_change.xlsx")

# %% [markdown]
# # Precipitations

# %%
list_results_rcp45 = []
list_results_rcp85 = []
list_results_ssp245 = []
list_results_ssp585 = []

for lat_val, lon_val in tqdm(zip(buildings_df.lat.values, buildings_df.lon.values)):
        
    dic_results_rcp45 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"precipitations_rcp45"}
    list_results_rcp45.append(dic_results_rcp45)
    dic_results_rcp85 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"precipitations_rcp85"}
    list_results_rcp85.append(dic_results_rcp85)
    dic_results_ssp245 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"precipitations_world_ssp245"}
    list_results_ssp245.append(dic_results_ssp245)
    dic_results_ssp585 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"precipitations_world_ssp585"}
    list_results_ssp585.append(dic_results_ssp585)

results_rcp45 = pd.DataFrame(make_precipitations(inputs=list_results_rcp45))
results_rcp85 = pd.DataFrame(make_precipitations(inputs=list_results_rcp85))
results_ssp245 = pd.DataFrame(make_precipitations(inputs=list_results_ssp245))
results_ssp585 = pd.DataFrame(make_precipitations(inputs=list_results_ssp585))
# Out:
# 1021it [00:00, 571060.73it/s]

# %%
results_ssp245.columns
# Out:
# Index(['building_mapping', 'collection_name', 'continent', 'continuous_score',
#        'data_source', 'discrete_score', 'lat_building', 'latitude',
#        'lon_building', 'longitude', 'nmb_xtr_days', 'position',
#        'rain_xtr_days'],
#       dtype='object')

# %% [markdown]
# # Merging and processing data

# %%
summary_df = pd.merge(buildings_df[["building_id", "building_name", "lat", "lon", "city", "country", "address"]],
                      results_rcp45[["continuous_score_precipitations", "discrete_score_precipitations", "lat_building", "lon_building"]],
                      how = "left",
                      left_on = ["lat", "lon"],
                      right_on = ["lat_building", "lon_building"])

summary_df = summary_df.drop_duplicates()

summary_df["rank_rcp45"] = summary_df['continuous_score_precipitations'].rank(method='min')

# %%
summary_df.head(2)
# Out:
#   building_id            building_name        lat       lon  \
# 0       I0014  I0014 - NEUILLY 179 CDG  48.883845  2.262274
# 1       I0181  I0181 - MONTREUIL ATLAS  48.849477  2.419210
#
#                 city country                           address  \
# 0  NEUILLY-SUR-SEINE  france  179-181 avenue Charles De Gaulle
# 1          Montreuil  france                  118 Rue de Lagny
#
#    continuous_score_precipitations  discrete_score_precipitations  \
# 0                        57.944788                              1
# 1                        57.944788                              1
#
#    lat_building  lon_building  rank_rcp45
# 0     48.883845      2.262274       372.0
# 1     48.849477      2.419210       372.0

# %%
summary_df = pd.merge(summary_df,
                      results_rcp85[["continuous_score_precipitations", "discrete_score_precipitations", "lat_building", "lon_building"]],
                      how = "left",
                      on = ["lat_building", "lon_building"],
                      suffixes = ("_rcp45", "_rcp85")
                     )

summary_df = summary_df.drop_duplicates()

summary_df["rank_rcp85"] = summary_df['continuous_score_precipitations_rcp85'].rank(method='min')

# %%
summary_df.head(2)
# Out:
#   building_id            building_name        lat       lon  \
# 0       I0014  I0014 - NEUILLY 179 CDG  48.883845  2.262274
# 1       I0181  I0181 - MONTREUIL ATLAS  48.849477  2.419210
#
#                 city country                           address  \
# 0  NEUILLY-SUR-SEINE  france  179-181 avenue Charles De Gaulle
# 1          Montreuil  france                  118 Rue de Lagny
#
#    continuous_score_precipitations_rcp45  discrete_score_precipitations_rcp45  \
# 0                              57.944788                                    1
# 1                              57.944788                                    1
#
#    lat_building  lon_building  rank_rcp45  \
# 0     48.883845      2.262274       372.0
# 1     48.849477      2.419210       372.0
#
#    continuous_score_precipitations_rcp85  discrete_score_precipitations_rcp85  \
# 0                             106.528734                                    1
# 1                             106.528734                                    1
#
#    rank_rcp85
# 0        95.0
# 1        95.0

# %%
summary_df = pd.merge(summary_df,
                      results_ssp245[['continuous_score', 'discrete_score', 'nmb_xtr_days', 'rain_xtr_days', "lat_building", "lon_building"]],
                      how = "left",
                      on = ["lat_building", "lon_building"],
                     )

summary_df = summary_df.drop_duplicates()

summary_df["rank_ssp245"] = summary_df['continuous_score'].rank(method='min')

# %%
summary_df.head(2)
# Out:
#   building_id            building_name        lat       lon  \
# 0       I0014  I0014 - NEUILLY 179 CDG  48.883845  2.262274
# 1       I0181  I0181 - MONTREUIL ATLAS  48.849477  2.419210
#
#                 city country                           address  \
# 0  NEUILLY-SUR-SEINE  france  179-181 avenue Charles De Gaulle
# 1          Montreuil  france                  118 Rue de Lagny
#
#    continuous_score_precipitations_rcp45  discrete_score_precipitations_rcp45  \
# 0                              57.944788                                    1
# 1                              57.944788                                    1
#
#    lat_building  lon_building  rank_rcp45  \
# 0     48.883845      2.262274       372.0
# 1     48.849477      2.419210       372.0
#
#    continuous_score_precipitations_rcp85  discrete_score_precipitations_rcp85  \
# 0                             106.528734                                    1
# 1                             106.528734                                    1
#
#    rank_rcp85  continuous_score  discrete_score  nmb_xtr_days  rain_xtr_days  \
# 0        95.0         19.271336             2.0     16.390476      78.488783
# 1        95.0         19.271336             2.0     16.390476      78.488783
#
#    rank_ssp245
# 0         49.0
# 1         49.0

# %%
summary_df = pd.merge(summary_df,
                      results_ssp585[['continuous_score', 'discrete_score', 'nmb_xtr_days', 'rain_xtr_days', "lat_building", "lon_building"]],
                      how = "left",
                      on = ["lat_building", "lon_building"],
                      suffixes = ("_ssp245", "_ssp585")
                     )

summary_df = summary_df.drop_duplicates().drop(columns = ["lat_building", "lon_building"])

summary_df["rank_ssp585"] = summary_df['continuous_score_ssp585'].rank(method='min')

# %%
summary_df.head(2)
# Out:
#   building_id            building_name        lat       lon  \
# 0       I0014  I0014 - NEUILLY 179 CDG  48.883845  2.262274
# 1       I0181  I0181 - MONTREUIL ATLAS  48.849477  2.419210
#
#                 city country                           address  \
# 0  NEUILLY-SUR-SEINE  france  179-181 avenue Charles De Gaulle
# 1          Montreuil  france                  118 Rue de Lagny
#
#    continuous_score_precipitations_rcp45  discrete_score_precipitations_rcp45  \
# 0                              57.944788                                    1
# 1                              57.944788                                    1
#
#    rank_rcp45  continuous_score_precipitations_rcp85  \
# 0       372.0                             106.528734
# 1       372.0                             106.528734
#
#    discrete_score_precipitations_rcp85  rank_rcp85  continuous_score_ssp245  \
# 0                                    1        95.0                19.271336
# 1                                    1        95.0                19.271336
#
#    discrete_score_ssp245  nmb_xtr_days_ssp245  rain_xtr_days_ssp245  \
# 0                    2.0            16.390476             78.488783
# 1                    2.0            16.390476             78.488783
#
#    rank_ssp245  continuous_score_ssp585  discrete_score_ssp585  \
# 0         49.0                18.839316                    2.0
# 1         49.0                18.839316                    2.0
#
#    nmb_xtr_days_ssp585  rain_xtr_days_ssp585  rank_ssp585
# 0             16.12381              54.21343         47.0
# 1             16.12381              54.21343         47.0

# %%
summary_df["diff_rank_ssp245_rcp45"] = summary_df["rank_ssp245"] - summary_df["rank_rcp45"]
summary_df["diff_rank_ssp585_rcp85"] = summary_df["rank_ssp585"] - summary_df["rank_rcp85"]

summary_df["diff_discrete_score_ssp245_rcp45"] = summary_df["discrete_score_ssp245"] - summary_df["discrete_score_precipitations_rcp45"]
summary_df["diff_discrete_score_ssp585_rcp85"] = summary_df["discrete_score_ssp585"] - summary_df["discrete_score_precipitations_rcp85"]

# %% [markdown]
# # Results

# %% [markdown]
# ## Change in raking among project's assets

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 4), sharex = True, sharey = True)

ax1.hist(summary_df["diff_rank_ssp245_rcp45"])
ax1.set_title(f"Change in ranking of {project} assets in RCP/SSP2-4.5")
ax2.hist(summary_df["diff_rank_ssp585_rcp85"])
ax2.set_title(f"Change in ranking of {project} assets in RCP/SSP5-8.5");

# %%
nb_bdgs = len(summary_df)
print(f"Split of change in ranking for {project} assets in RCP/SSP2-4.5 scenario")
summary_df['magnitude_of_ranking_chg_ssp245_rcp45'] = pd.cut(summary_df['diff_rank_ssp245_rcp45'], bins=[-nb_bdgs, -nb_bdgs/2, -nb_bdgs/10, nb_bdgs/10, nb_bdgs/2, nb_bdgs], labels = ["High decrease in raking", "Moderate decrease in raking", "Stable ranking", "Moderate increase in raking", "High increase in raking"], right=True)
summary_df['magnitude_of_ranking_chg_ssp245_rcp45'].value_counts()
# Out:
# Split of change in ranking for primonial assets in RCP/SSP2-4.5 scenario
# Moderate decrease in raking    471
# Moderate increase in raking    209
# High increase in raking        186
# Stable ranking                 119
# High decrease in raking         36
# Name: magnitude_of_ranking_chg_ssp245_rcp45, dtype: int64

# %%
print(f"Split of change in ranking for {project} assets in RCP/SSP5-8.5 scenario")
summary_df['magnitude_of_ranking_chg_ssp585_rcp85'] = pd.cut(summary_df['diff_rank_ssp585_rcp85'], bins=[-nb_bdgs, -nb_bdgs/2, -nb_bdgs/10, nb_bdgs/10, nb_bdgs/2, nb_bdgs], labels = ["High decrease in raking", "Moderate decrease in raking", "Stable ranking", "Moderate increase in raking", "High increase in raking"], right=True)
summary_df['magnitude_of_ranking_chg_ssp585_rcp85'].value_counts()
# Out:
# Split of change in ranking for primonial assets in RCP/SSP5-8.5 scenario
# Stable ranking                 579
# Moderate increase in raking    232
# Moderate decrease in raking    152
# High increase in raking         34
# High decrease in raking         24
# Name: magnitude_of_ranking_chg_ssp585_rcp85, dtype: int64

# %%
m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 4)

for i, row in summary_df[summary_df['magnitude_of_ranking_chg_ssp245_rcp45'] != 'Stable raking'].iterrows():
    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'High decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#007500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'Moderate decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#00D100",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'Moderate increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FFA500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)
    
    if row.magnitude_of_ranking_chg_ssp245_rcp45 == 'High increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FF0000",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp245)) + "<br> Old ranking: " + str(int(row.rank_rcp45))).add_to(m)
        
m.save(f"./{project}_greatest_change_in_ranking_ssp245_rcp45.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fd612b234d0613ceb630d9f8047a5aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fd612b234d0613ceb630d9f8047a5aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fd612b234d0613ceb630d9f8047a5aa = L.map(
#                 &quot;map_3fd612b234d0613ceb630d9f8047a5aa&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbae78792bf675a8ac675f242510d84d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3fd612b234d0613ceb630d9f8047a5aa);
#
#
#             var circle_842081e44fafa1289b4304b6bee9574d = L.circle(
#                 [48.8838446, 2.2622742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3fd612b234d0613ceb630d9f8047a5aa);
#
#
#         var popup_cea6fccb1a3ef83c24889f7e2cea4fac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_136b9dc893a5543f457f22d3eb9b447f = $(`&lt;div id=&quot;html_136b9dc893a5543f457f22d3eb9b447f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0014&lt;br&gt; New ranking: 49&lt;br&gt; Old ranking: 372&lt;/div&gt;`)[0];
#                 popup_cea6fccb1a3ef83c24889f7e2cea4fac.setContent(html_136b9dc893a5543f457f22d3eb9b447f);
#
#
#
#         circle_842081e44fafa1289b4304b6bee9574d.bindPopup(popup_cea6fccb1a3ef83c24889f7e2cea4fac)
#         ;
#
#
#
#
#             var circle_4ea71f88c03c21564b7e03f26608f975 = L.circle(
#                 [48.8494766, 2.4192098],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3fd612b234d0613ceb630d9f8047a5aa);
#
#
#         var popup_211d20bb772a843fbb1d0053f0623e2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86ac1064c4638d5ea1054ada9dbb12e0 = $(`&lt;div id=&quot;html_86ac1064c4638d5ea1054ada9dbb12e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0181&lt;br&gt; New ranking: 49&lt;br&gt; Old ranking: 372&lt;/div&gt;`)[0];
#                 popup_211d20bb772a843fbb1d0053f0623e2e.setContent(html_86ac1064c4638d5ea1054ada9dbb12e0);
#
#
#
#         circle_4ea71f88c03c21564b7e03f26608f975.bindPopup(popup_211d20bb772a843fbb1d0053f0623e2e)
#         ;
#
#
#
#
#             var circle_a051c98e2c30c2a1026bb54fa7bc05ed = L.circle(
#                 [50.6910987, 3.1801869],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3fd612b234d0613ceb630d9f8047a5aa);
#
#
#         var popup_57b749788bb7842bdb23892cd745e71f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e88174d62cf7436d76dbf4fdbc41fd99 = $(`&lt;div id=&quot;html_e88174d62cf7436d76dbf4fdbc41fd99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0103&lt;br&gt; New ranking: 745&lt;br&gt; Old ranking: 24&lt;/div&gt;`)[0];
#                 popup_57b749788bb7842bdb23892cd745e71f.setContent(html_e88174d62cf7436d76dbf4fdbc41fd99);
#
#
#
#         circle_a051c98e2c30c2a1026bb54fa7bc05ed.bindPopup(popup_57b749788bb7842bdb23892cd745e71f)
#         ;
#
#
#
#
#             var circle_128dd9d38433c41293a3e381b7309c45 = L.circle(
#                 [45.8024492, 4.7837361],
#                 {&quot;bubblingM

# %%
m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 4)

for i, row in summary_df[summary_df['magnitude_of_ranking_chg_ssp585_rcp85'] != 'Stable raking'].iterrows():
    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'High decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#007500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'Moderate decrease in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#00D100",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)

    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'Moderate increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FFA500",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)
    
    if row.magnitude_of_ranking_chg_ssp585_rcp85 == 'High increase in raking':
        folium.Circle(location = (row.lat, row.lon),
                     color = "#FF0000",
                     popup = "Building id: " + str(row.building_id) + "<br> New ranking: " + str(int(row.rank_ssp585)) + "<br> Old ranking: " + str(int(row.rank_rcp85))).add_to(m)
        
m.save(f"./{project}_greatest_change_in_ranking_ssp585_rcp85.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_472ba156801dd25e03e827e42c0c31f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_472ba156801dd25e03e827e42c0c31f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_472ba156801dd25e03e827e42c0c31f6 = L.map(
#                 &quot;map_472ba156801dd25e03e827e42c0c31f6&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd7db70b35356d75fef4ca7aa2c295b6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_472ba156801dd25e03e827e42c0c31f6);
#
#
#             var circle_a6ea0526d8f986ed3c8f3a95bb6a037b = L.circle(
#                 [50.6910987, 3.1801869],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFA500&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFA500&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_472ba156801dd25e03e827e42c0c31f6);
#
#
#         var popup_17417c4d19e31d6fe7c64e0c955792c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4d0583b1e29fb2c85bfd04d283b1947 = $(`&lt;div id=&quot;html_e4d0583b1e29fb2c85bfd04d283b1947&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0103&lt;br&gt; New ranking: 659&lt;br&gt; Old ranking: 446&lt;/div&gt;`)[0];
#                 popup_17417c4d19e31d6fe7c64e0c955792c7.setContent(html_e4d0583b1e29fb2c85bfd04d283b1947);
#
#
#
#         circle_a6ea0526d8f986ed3c8f3a95bb6a037b.bindPopup(popup_17417c4d19e31d6fe7c64e0c955792c7)
#         ;
#
#
#
#
#             var circle_4dc4f21989e9648c6edd38410356667e = L.circle(
#                 [47.9158474, 1.9018489],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_472ba156801dd25e03e827e42c0c31f6);
#
#
#         var popup_57de53bec183fdbb69af07a389616a66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c93145ab56d4b003a26043fa5ec81a5e = $(`&lt;div id=&quot;html_c93145ab56d4b003a26043fa5ec81a5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0169&lt;br&gt; New ranking: 37&lt;br&gt; Old ranking: 417&lt;/div&gt;`)[0];
#                 popup_57de53bec183fdbb69af07a389616a66.setContent(html_c93145ab56d4b003a26043fa5ec81a5e);
#
#
#
#         circle_4dc4f21989e9648c6edd38410356667e.bindPopup(popup_57de53bec183fdbb69af07a389616a66)
#         ;
#
#
#
#
#             var circle_85944024a22e387cb96e52cee6844162 = L.circle(
#                 [46.3174795, 4.811789999999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00D100&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00D100&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_472ba156801dd25e03e827e42c0c31f6);
#
#
#         var popup_e4c981321dd93e19e682a0f0faf6f934 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_704719ebe9fa79aecd1f7614835c170f = $(`&lt;div id=&quot;html_704719ebe9fa79aecd1f7614835c170f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0204&lt;br&gt; New ranking: 870&lt;br&gt; Old ranking: 987&lt;/div&gt;`)[0];
#                 popup_e4c981321dd93e19e682a0f0faf6f934.setContent(html_704719ebe9fa79aecd1f7614835c170f);
#
#
#
#         circle_85944024a22e387cb96e52cee6844162.bindPopup(popup_e4c981321dd93e19e682a0f0faf6f934)
#         ;
#
#
#
#
#             var circle_a1f99471953e204003117065b2bca8c0 = L.circle(
#                 [48.9276597, 1.986697],
#                 {&quot;

# %% [markdown]
# ## Change in discrete scores

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 4), sharex = True, sharey = True)

ax1.hist(summary_df["diff_discrete_score_ssp245_rcp45"], bins = np.linspace(-5.5, 5.5, 12), rwidth = 0.5)
ax1.set_title(f"Change in discrete score of {project} assets in RCP/SSP2-4.5")
ax1.set_xticks(np.linspace(-5, 5, 11))

ax2.hist(summary_df["diff_discrete_score_ssp585_rcp85"], bins = np.linspace(-5.5, 5.5, 12), rwidth = 0.5)
ax2.set_title(f"Change in discrete score of {project} assets in RCP/SSP5-8.5")
ax2.set_xticks(np.linspace(-5, 5, 11));

# %%
print(f"Split of change in discrete score for {project} assets in RCP/SSP2-4.5 scenario")
summary_df['magnitude_of_discrete_score_chg_ssp245_rcp45'] = pd.cut(summary_df['diff_discrete_score_ssp245_rcp45'], bins=[-5.5, -3.5, -1.5, 1.5, 3.5, 5.5], labels = ["High decrease in discrete score (-4 or -5 pts)", "Moderate decrease in discrete score (-2 or -3 pts)", "Stable discrete score (-1, +1 pt or no change)", "Moderate increase in discrete score (+2 or +3 pts)", "High increase in discrete score (+4 or +5 pts)"], right=True)
summary_df['magnitude_of_discrete_score_chg_ssp245_rcp45'].value_counts()
# Out:
# Split of change in discrete score for primonial assets in RCP/SSP2-4.5 scenario
# Stable discrete score (-1, +1 pt or no change)        517
# Moderate increase in discrete score (+2 or +3 pts)    247
# High increase in discrete score (+4 or +5 pts)        241
# Moderate decrease in discrete score (-2 or -3 pts)     16
# High decrease in discrete score (-4 or -5 pts)          0
# Name: magnitude_of_discrete_score_chg_ssp245_rcp45, dtype: int64

# %%
print(f"Percentage of assets whose discrete score remains stable for {project} in SSP2-4.5 scenario: {round(len(summary_df[summary_df['magnitude_of_discrete_score_chg_ssp245_rcp45'] == 'Stable discrete score (-1, +1 pt or no change)'])/len(summary_df)*100,1)}%")
# Out:
# Percentage of assets whose discrete score remains stable for primonial in SSP2-4.5 scenario: 50.6%

# %%
summary_df['diff_discrete_score_ssp245_rcp45'].value_counts()
# Out:
#  1.0    447
#  4.0    203
#  2.0    128
#  3.0    119
#  0.0     53
#  5.0     38
# -1.0     17
# -2.0      9
# -3.0      7
# Name: diff_discrete_score_ssp245_rcp45, dtype: int64

# %%
print(f"Split of change in discrete score for {project} assets in RCP/SSP5-8.5 scenario")
summary_df['magnitude_of_discrete_score_chg_ssp585_rcp85'] = pd.cut(summary_df['diff_discrete_score_ssp585_rcp85'], bins=[-5.5, -3.5, -1.5, 1.5, 3.5, 5.5], labels = ["High decrease in discrete score (-4 or -5 pts)", "Moderate decrease in discrete score (-2 or -3 pts)", "Stable discrete score (-1, +1 pt or no change)", "Moderate increase in discrete score (+2 or +3 pts)", "High increase in discrete score (+4 or +5 pts)"], right=True)
summary_df['magnitude_of_discrete_score_chg_ssp585_rcp85'].value_counts()
# Out:
# Split of change in discrete score for primonial assets in RCP/SSP5-8.5 scenario
# Stable discrete score (-1, +1 pt or no change)        553
# Moderate increase in discrete score (+2 or +3 pts)    436
# High increase in discrete score (+4 or +5 pts)         29
# Moderate decrease in discrete score (-2 or -3 pts)      3
# High decrease in discrete score (-4 or -5 pts)          0
# Name: magnitude_of_discrete_score_chg_ssp585_rcp85, dtype: int64

# %%
print(f"Percentage of assets whose discrete score remains stable for {project} in SSP5-8.5 scenario: {round(len(summary_df[summary_df['magnitude_of_discrete_score_chg_ssp585_rcp85'] == 'Stable discrete score (-1, +1 pt or no change)'])/len(summary_df)*100,1)}%")
# Out:
# Percentage of assets whose discrete score remains stable for primonial in SSP5-8.5 scenario: 54.2%

# %%
loc = 'Magnitude of changes in precipitations discrete scores for Primonial assets in SSP2-4.5 scenario'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   


m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 5)

#Defining groups:
stable = folium.FeatureGroup(name="Stable discrete score (0 or +/-1 pt)").add_to(m)
moderate_change = folium.FeatureGroup(name="Moderate change in discrete score (+/-2 or 3 pts)").add_to(m)
high_change = folium.FeatureGroup(name="High change in discrete score (+/-4 or 5 pts)").add_to(m)

for i, row in summary_df.iterrows():
    
    if row.magnitude_of_discrete_score_chg_ssp245_rcp45 in ['Stable discrete score (-1, +1 pt or no change)']:        
        stable.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "darkgreen",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_precipitations_rcp45))))

    elif row.magnitude_of_discrete_score_chg_ssp245_rcp45 in ['Moderate decrease in discrete score (-2 or -3 pts)', 'Moderate increase in discrete score (+2 or +3 pts)']:        
        moderate_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "blue",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_precipitations_rcp45))))
        
    elif row.magnitude_of_discrete_score_chg_ssp245_rcp45 in ['High decrease in discrete score (-4 or -5 pts)', 'High increase in discrete score (+4 or +5 pts)']:
        high_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "fuchsia",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_ssp245)) + "<br> Old disc. score: " + str(int(row.discrete_score_precipitations_rcp45))))        

folium.LayerControl().add_to(m)
m.get_root().html.add_child(folium.Element(title_html))

m.save(f"./{project}_greatest_change_in_discrete_score_ssp245_rcp45.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77bf641a0d12d66d829c2386013463ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Magnitude of changes in precipitations discrete scores for Primonial assets in SSP2-4.5 scenario&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77bf641a0d12d66d829c2386013463ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77bf641a0d12d66d829c2386013463ca = L.map(
#                 &quot;map_77bf641a0d12d66d829c2386013463ca&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d916aba528ac027cdaa9ac62a0329b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77bf641a0d12d66d829c2386013463ca);
#
#
#             var feature_group_d079b3b78d472a559a129cf1f8e87b55 = L.featureGroup(
#                 {}
#             ).addTo(map_77bf641a0d12d66d829c2386013463ca);
#
#
#             var circle_d1a713d84121f42035227392fa6b3fdf = L.circle(
#                 [48.8838446, 2.2622742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d079b3b78d472a559a129cf1f8e87b55);
#
#
#         var popup_227bdff90738a6e96f7c35f7cceaaaff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a12e9d751fa9353b63a9e1f192592216 = $(`&lt;div id=&quot;html_a12e9d751fa9353b63a9e1f192592216&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0014&lt;br&gt; New disc. score: 2&lt;br&gt; Old disc. score: 1&lt;/div&gt;`)[0];
#                 popup_227bdff90738a6e96f7c35f7cceaaaff.setContent(html_a12e9d751fa9353b63a9e1f192592216);
#
#
#
#         circle_d1a713d84121f42035227392fa6b3fdf.bindPopup(popup_227bdff90738a6e96f7c35f7cceaaaff)
#         ;
#
#
#
#
#             var circle_e5092a71e004ab646a04c20a4e897bd3 = L.circle(
#                 [48.8494766, 2.4192098],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d079b3b78d472a559a129cf1f8e87b55);
#
#
#         var popup_c3f559f86e018212584e451463342dab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94d34e19fc591712e9cbd3aefa261971 = $(`&lt;div id=&quot;html_94d34e19fc591712e9cbd3aefa261971&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0181&lt;br&gt; New disc. score: 2&lt;br&gt; Old disc. score: 1&lt;/div&gt;`)[0];
#                 popup_c3f559f86e018212584e451463342dab.setContent(html_94d34e19fc591712e9cbd3aefa261971);
#
#
#
#         circle_e5092a71e004ab646a04c20a4e897bd3.bindPopup(popup_c3f559f86e018212584e451463342dab)
#         ;
#
#
#
#
#             var circle_22bbf9a1d0a7674231dc6531613b417d = L.circle(
#                 [48.796792, 2.3218177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d079b3b78d472a559a129cf1f8e87b55);
#
#
#         var popup_be396748617f657c77094719281512fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9dccea558355abbc6ec67df979eaaf3 = $(`&lt;div id=&quot;html_a9dccea558355abbc6ec67df979eaaf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0008&lt;br&gt; New disc

# %%
loc = 'Magnitude of changes in precipitations discrete scores for Primonial assets in SSP5-8.5 scenario'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   


m = folium.Map(location = (48.02134766687152, 12.877171825314177), zoom_start = 5)

#Defining groups:
stable = folium.FeatureGroup(name="Stable discrete score (0 or +/-1 pt)").add_to(m)
moderate_change = folium.FeatureGroup(name="Moderate change in discrete score (+/-2 or 3 pts)").add_to(m)
high_change = folium.FeatureGroup(name="High change in discrete score (+/-4 or 5 pts)").add_to(m)

for i, row in summary_df.iterrows():
    
    if row.magnitude_of_discrete_score_chg_ssp585_rcp85 in ['Stable discrete score (-1, +1 pt or no change)']:        
        stable.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "darkgreen",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_ssp585)) + "<br> Old disc. score: " + str(int(row.discrete_score_precipitations_rcp85))))

    elif row.magnitude_of_discrete_score_chg_ssp585_rcp85 in ['Moderate decrease in discrete score (-2 or -3 pts)', 'Moderate increase in discrete score (+2 or +3 pts)']:        
        moderate_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "blue",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_ssp585)) + "<br> Old disc. score: " + str(int(row.discrete_score_precipitations_rcp85))))
        
    elif row.magnitude_of_discrete_score_chg_ssp585_rcp85 in ['High decrease in discrete score (-4 or -5 pts)', 'High increase in discrete score (+4 or +5 pts)']:
        high_change.add_child(folium.Circle(location = (row.lat, row.lon),
                     color = "fuchsia",
                     popup = "Building id: " + str(row.building_id) + "<br> New disc. score: " + str(int(row.discrete_score_ssp585)) + "<br> Old disc. score: " + str(int(row.discrete_score_precipitations_rcp85))))        

folium.LayerControl().add_to(m)
m.get_root().html.add_child(folium.Element(title_html))

m.save(f"./{project}_greatest_change_in_discrete_score_ssp585_rcp85.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f5af2f4265a3dc0d0b73cd1e51c70d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Magnitude of changes in precipitations discrete scores for Primonial assets in SSP5-8.5 scenario&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f5af2f4265a3dc0d0b73cd1e51c70d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f5af2f4265a3dc0d0b73cd1e51c70d2 = L.map(
#                 &quot;map_3f5af2f4265a3dc0d0b73cd1e51c70d2&quot;,
#                 {
#                     center: [48.02134766687152, 12.877171825314177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5467bba5963ba1648996e503d9b523f0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3f5af2f4265a3dc0d0b73cd1e51c70d2);
#
#
#             var feature_group_9a8fed530fe68e6294538b42438a2ffd = L.featureGroup(
#                 {}
#             ).addTo(map_3f5af2f4265a3dc0d0b73cd1e51c70d2);
#
#
#             var circle_cbfa918372e5827265f79a1811aa219b = L.circle(
#                 [48.8838446, 2.2622742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_9a8fed530fe68e6294538b42438a2ffd);
#
#
#         var popup_4af1fddd5b4d5e7a8af2c6c86b7bb888 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aee1aa3cc0b1a7cab82f8a1f7c187aa3 = $(`&lt;div id=&quot;html_aee1aa3cc0b1a7cab82f8a1f7c187aa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0014&lt;br&gt; New disc. score: 2&lt;br&gt; Old disc. score: 1&lt;/div&gt;`)[0];
#                 popup_4af1fddd5b4d5e7a8af2c6c86b7bb888.setContent(html_aee1aa3cc0b1a7cab82f8a1f7c187aa3);
#
#
#
#         circle_cbfa918372e5827265f79a1811aa219b.bindPopup(popup_4af1fddd5b4d5e7a8af2c6c86b7bb888)
#         ;
#
#
#
#
#             var circle_48962122639c2429b67964abb2502170 = L.circle(
#                 [48.8494766, 2.4192098],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_9a8fed530fe68e6294538b42438a2ffd);
#
#
#         var popup_f2b7c6a31e8a52b7cd9994689bf4badc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da5a5a3916344b0ca8e82aefa153956f = $(`&lt;div id=&quot;html_da5a5a3916344b0ca8e82aefa153956f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0181&lt;br&gt; New disc. score: 2&lt;br&gt; Old disc. score: 1&lt;/div&gt;`)[0];
#                 popup_f2b7c6a31e8a52b7cd9994689bf4badc.setContent(html_da5a5a3916344b0ca8e82aefa153956f);
#
#
#
#         circle_48962122639c2429b67964abb2502170.bindPopup(popup_f2b7c6a31e8a52b7cd9994689bf4badc)
#         ;
#
#
#
#
#             var circle_0411eaf9303db9f25e4cc6580f21c977 = L.circle(
#                 [48.796792, 2.3218177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_9a8fed530fe68e6294538b42438a2ffd);
#
#
#         var popup_fc7ffc55a1beb1c00565e00334702fae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1280e1dfdaf2f30787e0d3314d45fa86 = $(`&lt;div id=&quot;html_1280e1dfdaf2f30787e0d3314d45fa86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Building id: I0008&lt;br&gt; New disc

# %% [markdown]
# # Saving summary excel

# %%
summary_df = summary_df.reset_index(drop = True)
summary_df.to_excel(f"./{project}_summary_precipitations_change.xlsx")

# %%
list_results_ssp245 = []
list_results_ssp585 = []

for lat_val, lon_val in tqdm(zip(buildings_df.lat.values, buildings_df.lon.values)):
        
    dic_results_ssp245 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"clay_subsidence_ssp245"}
    list_results_ssp245.append(dic_results_ssp245)
    dic_results_ssp585 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"clay_subsidence_ssp585"}
    list_results_ssp585.append(dic_results_ssp585)

results_ssp245 = pd.DataFrame(make_clay_subsidence(inputs=list_results_ssp245))
results_ssp585 = pd.DataFrame(make_clay_subsidence(inputs=list_results_ssp585))
# Out:
# 1021it [00:00, 95490.89it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 11
#       8     dic_results_ssp585 = {"lat" : lat_val, "lon" : lon_val, "collection_name":"clay_subsidence_ssp585"}
#       9     list_results_ssp585.append(dic_results_ssp585)
# ---> 11 results_ssp245 = pd.DataFrame(make_clay_subsidence(inputs=list_results_ssp245))
#      12 results_ssp585 = pd.DataFrame(make_clay_subsidence(inputs=list_results_ssp585))
#
# NameError: name 'make_clay_subsidence' is not defined
